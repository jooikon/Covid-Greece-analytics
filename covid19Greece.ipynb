# %%
import pandas as pd

# Φόρτωσε τα δεδομένα
df = pd.read_csv('owid-covid-data.csv')

# Δες τις πρώτες γραμμές
print(df.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
print(df.isnull().sum())
# Out:
# iso_code                                        0
# continent                                   26525
# location                                        0
# date                                            0
# total_cases                                 17631
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       416024
# excess_mortality_cumulative                416024
# excess_mortality                           416024
# excess_mortality_cumulative_per_million    416024
# Length: 67, dtype: int64

# %%
print(df.describe())
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  4.118040e+05  4.101590e+05        4.089290e+05  4.118040e+05
# mean   7.365292e+06  8.017360e+03        8.041026e+03  8.125957e+04
# std    4.477582e+07  2.296649e+05        8.661611e+04  4.411901e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00  0.000000e+00
# 25%    6.280750e+03  0.000000e+00        0.000000e+00  4.300000e+01
# 50%    6.365300e+04  0.000000e+00        1.200000e+01  7.990000e+02
# 75%    7.582720e+05  0.000000e+00        3.132860e+02  9.574000e+03
# max    7.758668e+08  4.423623e+07        6.319461e+06  7.057132e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  410608.000000        409378.000000            411804.000000
# mean       71.852139            72.060873            112096.199396
# std      1368.322990           513.636567            162240.412419
# min         0.000000             0.000000                 0.000000
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
greece_df = df[df['location'] == 'Greece']
print(greece_df.head())
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 145433      GRC    Europe   Greece 2020-01-05          0.0        0.0
# 145434      GRC    Europe   Greece 2020-01-06          0.0        0.0
# 145435      GRC    Europe   Greece 2020-01-07          0.0        0.0
# 145436      GRC    Europe   Greece 2020-01-08          0.0        0.0
# 145437      GRC    Europe   Greece 2020-01-09          0.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 145433                 NaN           0.0         0.0                  NaN
# 145434                 NaN           0.0         0.0                  NaN
# 145435                 NaN           0.0         0.0                  NaN
# 145436                 NaN           0.0         0.0                  NaN
# 145437                 NaN           0.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=greece_df, x='date', y='new_cases')
plt.title('Ημερήσια νέα κρούσματα στην Ελλάδα')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέα κρούσματα')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=greece_df, x='date', y='new_deaths', color='red')
plt.title('Ημερήσιοι νέοι θάνατοι COVID-19 στην Ελλάδα')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέοι θάνατοι')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
import pandas as pd

# Φόρτωσε τα δεδομένα
df = pd.read_csv('owid-worldcovid-data.csv')

# Δες τις πρώτες γραμμές
print(df.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
greece_df = df[df['location'] == 'Greece']

# %%
greece_df['date'] = pd.to_datetime(greece_df['date'])
# Out:
# C:\Users\Bill&Jo\AppData\Local\Temp\ipykernel_14464\936212313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   greece_df['date'] = pd.to_datetime(greece_df['date'])

# %%
greece_df = greece_df[(greece_df['date'] >= '2020-01-01') & (greece_df['date'] <= '2025-12-31')]

# %%
greece_df['people_vaccinated'] = greece_df['people_vaccinated'].fillna(method='ffill')
# Out:
# C:\Users\Bill&Jo\AppData\Local\Temp\ipykernel_14464\3530627034.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   greece_df['people_vaccinated'] = greece_df['people_vaccinated'].fillna(method='ffill')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.style.use('ggplot')  # ή 'default' αν δεν έχεις το ggplot

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['people_vaccinated'], color='green', label='Εμβολιασμένοι (τουλάχιστον μία δόση)')

plt.title('Εξέλιξη εμβολιασμών στην Ελλάδα (2020–2025)')
plt.xlabel('Ημερομηνία')
plt.ylabel('Άτομα')
plt.legend()

# Κάνε τις ημερομηνίες πιο καθαρές: δείξε κάθε χρόνο
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %%
# Αν δεν το έχεις κάνει ήδη:
greece_df['people_vaccinated'] = greece_df['people_vaccinated'].fillna(method='ffill')

# Αν θες, γέμισε και το population (κανονικά δεν αλλάζει, αλλά για σιγουριά):
greece_df['population'] = greece_df['population'].fillna(method='ffill')

# Φτιάξε νέα στήλη:
greece_df['unvaccinated'] = greece_df['population'] - greece_df['people_vaccinated']
# Out:
# C:\Users\Bill&Jo\AppData\Local\Temp\ipykernel_14464\1731019010.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   greece_df['people_vaccinated'] = greece_df['people_vaccinated'].fillna(method='ffill')
# C:\Users\Bill&Jo\AppData\Local\Temp\ipykernel_14464\1731019010.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   greece_df['population'] = greece_df['population'].fillna(method='ffill')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.style.use('ggplot')  # ή 'default'

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['unvaccinated'], color='red', label='Ανεμβολίαστοι')

plt.title('Εξέλιξη ανεμβολίαστων στην Ελλάδα (2020–2025)')
plt.xlabel('Ημερομηνία')
plt.ylabel('Άτομα')
plt.legend()

plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
plt.show()

# %%
# Μετατροπή σε datetime αν δεν έχει γίνει
greece_df['date'] = pd.to_datetime(greece_df['date'])

# Ομαδοποίηση ανά μήνα και μέσος όρος
monthly_cases = greece_df.resample('M', on='date')['new_cases'].mean()

plt.figure(figsize=(12,6))
plt.plot(monthly_cases.index, monthly_cases.values, color='orange')
plt.title('Μηνιαίος μέσος όρος νέων κρουσμάτων στην Ελλάδα')
plt.xlabel('Μήνας')
plt.ylabel('Μέσος όρος νέων κρουσμάτων')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bill&Jo\AppData\Local\Temp\ipykernel_14464\3581674132.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_cases = greece_df.resample('M', on='date')['new_cases'].mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['people_vaccinated'] / greece_df['population'] * 100, 
         color='green', label='Ποσοστό εμβολιασμένων (%)')
plt.plot(greece_df['date'], greece_df['unvaccinated'] / greece_df['population'] * 100, 
         color='red', label='Ποσοστό ανεμβολίαστων (%)')
plt.title('Ποσοστά εμβολιασμένων και ανεμβολίαστων στην Ελλάδα')
plt.xlabel('Ημερομηνία')
plt.ylabel('Ποσοστό (%)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['new_cases'], label='Νέα κρούσματα (ημερήσια)', color='blue')
plt.plot(greece_df['date'], greece_df['new_deaths'], label='Νέοι θάνατοι (ημερήσια)', color='red')
plt.title('Νέα κρούσματα και νέοι θάνατοι στην Ελλάδα')
plt.xlabel('Ημερομηνία')
plt.ylabel('Αριθμός')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
greece_df = df[df['location'] == 'Greece'].copy()
greece_df['date'] = pd.to_datetime(greece_df['date'])

# %%
europe_df = df[df['location'] == 'Europe'].copy()
europe_df['date'] = pd.to_datetime(europe_df['date'])

# %%
europe_grouped = europe_df.groupby('date').agg({
    'new_cases': 'sum',
    'new_deaths': 'sum',
    'population': 'sum',
    'people_vaccinated': 'sum'
}).reset_index()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['new_cases'], label='Ελλάδα', color='blue')
plt.plot(europe_grouped['date'], europe_grouped['new_cases'], label='Ευρώπη (σύνολο)', color='green')
plt.title('Σύγκριση νέων κρουσμάτων: Ελλάδα vs Ευρώπη')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέα κρούσματα')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Δημιουργούμε στήλες με κρούσματα ανά εκατομμύριο
greece_df['new_cases_per_million'] = greece_df['new_cases'] / greece_df['population'] * 1_000_000
europe_grouped['new_cases_per_million'] = europe_grouped['new_cases'] / europe_grouped['population'] * 1_000_000

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['new_cases_per_million'], label='Ελλάδα', color='blue')
plt.plot(europe_grouped['date'], europe_grouped['new_cases_per_million'], label='Ευρώπη (ανά εκατομμύριο)', color='green')
plt.title('Σύγκριση νέων κρουσμάτων ανά εκατομμύριο: Ελλάδα vs Ευρώπη')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέα κρούσματα / εκατομμύριο')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
greece_df = df[df['location'] == 'Greece'].copy()
greece_df['date'] = pd.to_datetime(greece_df['date'])

# %%
europe_df = df[df['location'] == 'Europe'].copy()
europe_df['date'] = pd.to_datetime(europe_df['date'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['new_deaths'], label='Ελλάδα', color='red')
plt.plot(europe_grouped['date'], europe_grouped['new_deaths'], label='Ευρώπη (σύνολο)', color='purple')
plt.title('Σύγκριση νέων θανάτων: Ελλάδα vs Ευρώπη')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέοι θάνατοι')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['people_vaccinated'], label='Ελλάδα', color='green')
plt.plot(europe_grouped['date'], europe_grouped['people_vaccinated'], label='Ευρώπη (σύνολο)', color='blue')
plt.title('Σύγκριση εμβολιασμένων: Ελλάδα vs Ευρώπη')
plt.xlabel('Ημερομηνία')
plt.ylabel('Άτομα με τουλάχιστον μία δόση')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
greece_df['new_deaths_per_million'] = greece_df['new_deaths'] / greece_df['population'] * 1_000_000
europe_grouped['new_deaths_per_million'] = europe_grouped['new_deaths'] / europe_grouped['population'] * 1_000_000

plt.figure(figsize=(12,6))
plt.plot(greece_df['date'], greece_df['new_deaths_per_million'], label='Ελλάδα', color='red')
plt.plot(europe_grouped['date'], europe_grouped['new_deaths_per_million'], label='Ευρώπη (ανά εκατομμύριο)', color='purple')
plt.title('Νέοι θάνατοι ανά εκατομμύριο: Ελλάδα vs Ευρώπη')
plt.xlabel('Ημερομηνία')
plt.ylabel('Νέοι θάνατοι / εκατομμύριο')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
